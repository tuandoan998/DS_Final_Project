# %%
import pandas as pd

# %%
tiki_df = pd.read_csv('../dataset/tiki.csv', sep='\t')
tiki_df.head()
# Out:
#                                                  url  \
# 0  https://tiki.vn/dien-thoai-iphone-11-128gb-han...
# 1  https://tiki.vn/dien-thoai-oppo-f7-64gb-4gb-ha...
# 2  https://tiki.vn/dien-thoai-samsung-galaxy-m10-...
# 3  https://tiki.vn/dien-thoai-oppo-f11-pro-6gb-64...
# 4  https://tiki.vn/dien-thoai-vsmart-live-64gb-6g...
#
#                                                title provider  \
# 0      Điện Thoại iPhone 11 128GB  - Hàng Chính Hãng    Apple
# 1    Điện Thoại OPPO F7 (64GB/4GB) - Hàng Chính Hãng     OPPO
# 2  Điện Thoại Samsung Galaxy M10 (16GB/2GB) - Hàn...  Samsung
# 3  Điện Thoại OPPO F11 Pro (6GB/64GB) - Hàng Chín...     OPPO
# 4  Điện thoại Vsmart Live (64GB/6GB) - Hàng chính...   Vsmart
#
#                                              monitor                     os  \
# 0  Công nghệ màn hình: IPS LCD Màn hình rộng: 6.1...  Hệ điều hành: iOS 13
# 1                               Màn hình: 6.23 inch                     NaN
# ...

# %%
tiki_df.isnull().sum()
# Out:
# url            0
# title          0
# provider       0
# monitor        7
# os           224
# front_cam     23
# back_cam     118
# cpu           31
# ram           23
# rom           40
# SD           240
# SIM          103
# battery      182
# dtype: int64
